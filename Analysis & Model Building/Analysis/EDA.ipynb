# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
ROOT_DIR = Path().resolve().parent
WORKING_DIR = Path().resolve()
ROOT_DIR
# Out:
# WindowsPath('C:/Users/Duong/Desktop/ML/Analysis & Model Building')

# %%
df = pd.read_csv(ROOT_DIR / 'Data' / 'raw_data.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. Đọc hiểu dữ liệu

# %% [markdown]
# Tóm tắt các column:
#
#
# ---
#
# ---
#
#
# 1. **Age (Tuổi)**: Độ tuổi của nhân viên.
#
# 2. **Attrition (Tình trạng nghỉ việc)**: Biến mục
# tiêu, chỉ ra liệu nhân viên đã nghỉ việc hay không.
#
# 3. **BusinessTravel (Chuyến đi công tác)**: Tần suất đi công tác của nhân viên.
#
# 4. **DailyRate (Tỉ lệ lương hàng ngày)**: Mức lương hàng ngày của nhân viên.
#
# 5. **Department (Bộ phận công việc)**: Bộ phận hoặc phòng ban trong tổ chức mà nhân viên thuộc về.
#
# 6. **DistanceFromHome (Khoảng cách từ nhà đến nơi làm việc)**: Khoảng cách từ nơi ở của nhân viên đến nơi làm việc.
#
# 7. **Education (Trình độ học vấn)**: Mức độ học vấn của nhân viên, có thể là tiến sĩ, thạc sĩ, bằng cử nhân, vv.
#
# 8. **EducationField (Ngành học)**: Lĩnh vực học vấn hoặc chuyên ngành của nhân viên.
#
# 9. **EmployeeCount (Số lượng nhân viên)**: Số lượng nhân viên trong mẫu dữ liệu này, thường là 1.
#
# 10. **EmployeeNumber (Số nhân viên)**: Mã số nhân viên hoặc mã nhân viên.
#
# 11. **EnvironmentSatisfaction (Mức độ hài lòng với môi trường làm việc)**: Đánh giá về môi trường làm việc của nhân viên.
#
# 12. **Gender (Giới tính)**: Giới tính của nhân viên.
#
# 13. **HourlyRate (Tỉ lệ lương hàng giờ)**: Mức lương được trả theo giờ của nhân viên.
#
# 14. **JobInvolvement (Sự hứng thú với công việc)**: Mức độ hứng thú của nhân viên đối với công việc của họ.
#
# 15. **JobLevel (Cấp bậc công việc)**: Cấp bậc hoặc vị trí công việc của nhân viên trong tổ chức.
#
# 16. **JobRole (Vai trò công việc)**: Vai trò hoặc chức vụ công việc của nhân viên trong tổ chức.
#
# 17. **JobSatisfaction (Sự hài lòng với công việc)**: Mức độ hài lòng của nhân viên về công việc của họ.
#
# 18. **MaritalStatus (Tình trạng hôn nhân)**: Tình trạng hôn nhân của nhân viên.
#
# 19. **MonthlyIncome (Thu nhập hàng tháng)**: Mức thu nhập hàng tháng của nhân viên.
#
# 20. **MonthlyRate (Tỉ lệ lương hàng tháng)**: Mức lương được trả hàng tháng của nhân viên.
#
# 21. **NumCompaniesWorked (Số lượng công ty đã làm việc)**: Số lượng công ty mà nhân viên đã làm việc trước đó.
#
# 22. **Over18 (Trên 18 tuổi)**: Chỉ ra liệu nhân viên có trên 18 tuổi hay không.
#
# 23. **OverTime (Làm thêm giờ)**: Chỉ ra liệu nhân viên có làm thêm giờ hay không.
#
# 24. **PercentSalaryHike (Tăng lương phần trăm)**: Tỷ lệ tăng lương phần trăm gần đây.
#
# 25. **PerformanceRating (Đánh giá hiệu suất)**: Đánh giá hiệu suất công việc của nhân viên.
#
# 26. **RelationshipSatisfaction (Sự hài lòng trong mối quan hệ)**: Mức độ hài lòng của nhân viên về mối quan hệ cá nhân.
#
# 27. **StandardHours (Giờ làm việc chuẩn)**: Số giờ làm việc chuẩn trong một tuần.
#
# 28. **StockOptionLevel (Mức độ tùy chọn cổ phiếu)**: Mức độ tùy chọn cổ phiếu mà nhân viên có.
#
# 29. **TotalWorkingYears (Tổng số năm làm việc)**: Tổng số năm mà nhân viên đã làm việc.
#
# 30. **TrainingTimesLastYear (Số lần đào tạo trong năm)**: Số lần đào tạo mà nhân viên đã tham gia trong năm qua.
#
# 31. **WorkLifeBalance (Sự cân bằng giữa công việc và cuộc sống)**: Mức độ cân bằng giữa công việc và cuộc sống của nhân viên.
#
# 32. **YearsAtCompany (Số năm làm việc tại công ty)**: Số năm mà nhân viên đã làm việc tại công ty hiện tại.
#
# 33. **YearsInCurrentRole (Số năm ở vị trí hiện tại)**: Số năm mà nhân viên đã ở trong vị trí công việc hiện tại.
#
# 34. **YearsSinceLastPromotion (Số năm kể từ lần thăng chức cuối cùng)**: Số năm kể từ lần thăng chức cuối cùng của nhân viên.
#
# 35. **YearsWithCurrManager (Số năm với quản lý hiện tại)**: Số năm mà nhân viên đã làm việc dưới sự quản lý của quản lý hiện tại.

# %% [markdown]
# ## 2. Phân tích đơn biến

# %%
df.select_dtypes(include='object')
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %% [markdown]
# ### 2.1. Cột dạng object

# %% [markdown]
# Trước hết ta xem các cột dữ liệu dạng 'object'

# %%
for col in df.select_dtypes(include='object').columns:
    print('Column {}, values: {}'.format(col, df[col].unique()))
    print('-'*50)
# Out:
# Column Attrition, values: ['Yes' 'No']
# --------------------------------------------------
# Column BusinessTravel, values: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# --------------------------------------------------
# Column Department, values: ['Sales' 'Research & Development' 'Human Resources']
# --------------------------------------------------
# Column EducationField, values: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# --------------------------------------------------
# Column Gender, values: ['Female' 'Male']
# --------------------------------------------------
# Column JobRole, values: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# --------------------------------------------------
# Column MaritalStatus, values: ['Single' 'Married' 'Divorced']
# ...

# %% [markdown]
# Cột **Over18** chứa duy nhất 1 giá trị nên không có ý nghĩa khi tiến hành phân loại

# %% [markdown]
# ### 2.2. Cột dạng số

# %%
df.select_dtypes(exclude='object')
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
df['EmployeeCount'].unique()
# Out:
# array([1], dtype=int64)

# %%
len(df['EmployeeNumber'].unique())
# Out:
# 1470

# %%
df['StandardHours'].unique()
# Out:
# array([80], dtype=int64)

# %% [markdown]
# $\rightarrow$ Như vậy, cột **EmployeeCount, StandardHours** cũng chỉ chứa duy nhất 1 giá trị
#
#
# Ngoài ra, có thể thấy EmployeeNumber là mã số duy nhất ứng với mỗi nhân viên. Ta có thể loại bỏ 3 cột này khi phân tích vì chúng không mang lại ý nghĩa

# %% [markdown]
# ### 2.3. Phân phối các cột dạng số

# %% [markdown]
# Tiếp theo ta xem xét phân phối của các cột

# %%
distr_col = df.select_dtypes(exclude='object').drop(columns=['EmployeeCount', 'EmployeeNumber', 'StandardHours']).columns
len(distr_col)
# Out:
# 23

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axes = plt.subplots(nrows=8, ncols=3, figsize=(12, 30)) 

for i, ax in enumerate(axes.flat):  
    if i < 23:
        sns.histplot(data=df[distr_col[i]],
                    kde=True, ax=ax)
        ax.set_title(f'{distr_col[i]}\n'
                    f'Mean: {df[distr_col[i]].mean():.2f},  Std: {df[distr_col[i]].std():.2f} \n'
                    f'Min: {df[distr_col[i]].min():.2f},   Max: {df[distr_col[i]].max():.2f}\n' 
                    f'Median: {df[distr_col[i]].median():.2f}')
        ax.set_xlabel('')
    
plt.tight_layout() 
plt.show()

# %% [markdown]
# Một số thông tin nhận được:
# * Độ tuổi của nhân viên chủ yếu thuộc khoảng 30 - 40 tuổi
# * Mức lương hàng ngày phân bố rộng, mức cao nhất $1500, gấp hơn 10 lần so với mức thấp nhất $102, điều này cũng tương tự cho mức lương theo tháng
# * Số đông nhân viên hài lòng với công việc, môi trường và quan hệ cá nhân. Tuy nhiên vẫn còn một lượng khá đông nhân viên tỏ ra không hài lòng với các yếu tố này
# * Hầu hết nhân viên đều làm việc tại công ty dưới 10 năm

# %% [markdown]
# Xem xét biến mục tiêu (Attrition)

# %%
count_values = df['Attrition'].value_counts()
plt.figure(figsize=(14, 6))
plt.subplot(1,2,1)
sns.barplot(x = count_values.index,
            y = count_values.values, palette="Set2")
plt.title('Attrition count')
plt.ylabel('Number of Employees')
plt.subplot(1,2,2)
sns.barplot(x = count_values.index,
            y = count_values.values / sum(count_values.values) * 100, palette="Set2")
plt.title('Attrition percentage (%)')
plt.ylabel('Percentage')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\203777646.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = count_values.index,
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\203777646.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = count_values.index,
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# Có sự chênh lệch rất lớn: gần **85%** nhân viên nghỉ việc

# %% [markdown]
# ## 3. Phân tích đa biến

# %% [markdown]
# ### 3.1. Phân tích theo giới tính

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %% [markdown]
# #### 3.1.1. Sự nghỉ việc

# %%
female = df[df['Gender'] == 'Female']['Attrition'].value_counts()
male = df[df['Gender'] == 'Male']['Attrition'].value_counts()
plt.figure(figsize=(14, 6))
plt.subplot(1,2,1)
sns.barplot(x = female.index,
            y = female.values / sum(female.values) * 100, palette="Set2")
plt.title('Attrition Perentage in Female')
plt.ylabel('Percentage')
plt.subplot(1,2,2)
sns.barplot(x = male.index,
            y = male.values / sum(male.values) * 100, palette="Set2")
plt.title('Attrition Perentage in Male')
plt.ylabel('Percentage')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2687448329.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = female.index,
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2687448329.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = male.index,
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# Có thể thấy giới tính không có nhiều tác động đến sự nghỉ việc

# %%
def gender_dist_by_col(col_name = 'DailyRate'):
    female = df[df['Gender'] == 'Female'][col_name]
    male = df[df['Gender'] == 'Male'][col_name]
    
    plt.figure(figsize=(12, 6))
    plt.subplot(1,2,1)
    # Female distribution
    sns.kdeplot(female, fill=True, color='pink', label='Female')
    plt.axvline(x=female.mean(), linestyle='--', color='red', label='Mean Female ' + col_name)

    # Male age distribution
    sns.kdeplot(male, fill=True, color='lightblue', label='Male')
    plt.axvline(x=male.mean(), linestyle='--', color='blue', label='Mean Male ' + col_name)

    plt.title(col_name + ' Distribution by Gender')
    plt.xlabel(col_name)
    plt.ylabel('Density')
    plt.legend()

    plt.subplot(1,2,2)
    female = df[df['Gender'] == 'Female']
    male = df[df['Gender'] == 'Male']
    sns.histplot(female, x=col_name, kde=True, color='red', label='Female')
    sns.histplot(male, x=col_name, kde=True, color='lightblue', label='Male')
    plt.title(col_name + ' Distribution by Gender')
    plt.xlabel(col_name)
    plt.ylabel('Count')
    plt.legend()
    plt.show()

# %% [markdown]
# #### 3.1.2. Độ tuổi

# %%
gender_dist_by_col('Age')

# %% [markdown]
# Phân bố độ tuổi ở cả hai giới gần như tương tự nhau

# %% [markdown]
# #### 3.1.3. Thu nhập

# %%
gender_dist_by_col('MonthlyIncome')

# %%
gender_dist_by_col('MonthlyRate')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Gender', y='MonthlyRate')
plt.title('MonthlyRate by Gender\n'
          f'Female: avg = {df[df['Gender'] == 'Female']['MonthlyRate'].mean():.2f}\n'
          f'Male: avg = {df[df['Gender'] == 'Male']['MonthlyRate'].mean():.2f}\n')
# Out:
# Text(0.5, 1.0, 'MonthlyRate by Gender\nFemale: avg = 14674.60\nMale: avg = 14072.11\n')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Gender', y='MonthlyIncome')
plt.title('MonthlyIncome by Gender')
plt.title('MonthlyIncome by Gender\n'
          f'Female: avg = {df[df['Gender'] == 'Female']['MonthlyIncome'].mean():.2f}\n'
          f'Male: avg = {df[df['Gender'] == 'Male']['MonthlyIncome'].mean():.2f}\n')
# Out:
# Text(0.5, 1.0, 'MonthlyIncome by Gender\nFemale: avg = 6686.57\nMale: avg = 6380.51\n')

# %%
def pie_plot_by_gender(col_name = 'Attrition'):
    female = df[df['Gender'] == 'Female']
    male = df[df['Gender'] == 'Male']
    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.pie(female[col_name].value_counts().values, labels=female[col_name].value_counts().keys(),  autopct='%.0f%%')
    plt.title(f'{col_name} in Female')
    plt.subplot(1,2,2)
    plt.pie(male[col_name].value_counts().values, labels=male[col_name].value_counts().keys(),  autopct='%.0f%%')
    plt.title(f'{col_name} in Male')
    plt.show()

# %%
pie_plot_by_gender('Attrition')

# %% [markdown]
# * Về cơ bản, phân bố mức lương và thu nhập ở cả 2 giới là như nhau, tập trung chủ yếu ở mức trên $2500 đến khoảng $8750.
#
# * Mức lương cao ít phổ biến ở cả 2 giới. Mặc dù vậy, nam giới cho thấy có nhiều mức thu nhập cao hơn so với nữ (nhiều outlier hơn)

# %% [markdown]
# #### 3.1.4. Mức độ hài lòng

# %%
pie_plot_by_gender('JobSatisfaction')

# %%
def attrition_count_by_gender(col_name='JobSatisfaction', percentage=False):
    plt.figure(figsize=(12, 6))
    
    for i, gender in enumerate(['Female', 'Male'], 1):
        plt.subplot(1, 2, i)
        df_gender = df[df['Gender'] == gender]
        attrition_counts = df_gender.groupby(col_name)['Attrition'].count()
        
        if percentage:
            attrition_counts = (attrition_counts / attrition_counts.sum()) * 100
            ylabel = 'Attrition Percentage'
        else:
            ylabel = 'Attrition Count'
        
        sns.barplot(
            x=attrition_counts.index, 
            y=attrition_counts.values, 
            palette='tab10'
        )
        
        plt.ylabel(ylabel)
        plt.title(f'Attrition in {gender}')
    
    plt.tight_layout()
    plt.show()

# %%
attrition_count_by_gender(percentage=True)
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2216850159.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2216850159.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# * Có thể thấy mặc dù hài lòng với công việc, nhưng nhóm 3 và 4 vẫn có xu hướng rời bỏ công ty nhiều hơn

# %% [markdown]
# #### 3.1.5. Hiệu suất làm việc

# %%
pie_plot_by_gender('PerformanceRating')

# %%
attrition_count_by_gender('PerformanceRating', percentage=True)
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2216850159.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2216850159.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# #### 3.1.5. Tăng ca

# %%
pie_plot_by_gender('OverTime')

# %%
attrition_count_by_gender('OverTime', True)
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2216850159.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2216850159.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# #### Kết luận 1.
#
# * Có thể thấy mức độ hài lòng với công việc, hiệu suất công việc hay sự nghỉ việc đều như nhau ở cả hai giới.
#
# * Mức lương và thu nhập về cơ bản giống nhau ở cả hai giới.

# %% [markdown]
# ### 3.2. Phân tích mức lương được trả

# %% [markdown]
# #### 3.2.1. Theo số năm làm việc tại công ty

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, y='MonthlyRate', x='YearsAtCompany', hue='Gender')
plt.grid(True, linestyle='--', alpha=0.7)

# %%
def working_rank(x):
    if x < 5:
        return 'Under 5 years'
    elif x <= 10:
        return '5 - 10 years'
    elif x <= 20:
        return '10 - 20 years'
    else:
        return 'Over 20 years'

df['WorkingYearsRank'] = df['TotalWorkingYears'].apply(working_rank)
df['CompanyWorkingYearsRank'] = df['YearsAtCompany'].apply(working_rank)

# %%
monthly_rate_by_working_years = df.groupby('CompanyWorkingYearsRank').MonthlyRate.mean().reset_index().sort_index()
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(data=monthly_rate_by_working_years,
            x = 'CompanyWorkingYearsRank',
            y = 'MonthlyRate',
            palette='tab10')
plt.xlabel('Years At Company')

plt.subplot(1,2,2)
attr_by_working_years = df.groupby('CompanyWorkingYearsRank').Attrition.count().reset_index().sort_index()
sns.barplot(data=attr_by_working_years,
            x = 'CompanyWorkingYearsRank',
            y = 'Attrition',
            palette='tab10')
plt.xlabel('Years At Company')
plt.ylabel('Attrition Count')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2401980178.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly_rate_by_working_years,
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2401980178.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=attr_by_working_years,
# Text(0, 0.5, 'Attrition Count')

# %% [markdown]
# * Mức lương giữa theo số năm làm việc không có quá nhiều chênh lệch giữa các nhóm
#
# * Mặc dù vậy, các nhân viên lâu năm (trên 10 năm) có xu hướng ở lại công ty, trong khi các nhân viên làm việc tại công ty dưới 10 năm lại có xu hướng rời đi nhiều hơn

# %% [markdown]
# #### 3.2.2. Theo trình độ đào tạo / học vấn

# %%
edu = df['Education'].unique()
plt.figure(figsize=(12,8))
plt.subplots(nrows=2, ncols=3, figsize=(12,8))
for i in range(1, len(edu) + 1):
    plt.subplot(2, 3, i)
    sns.histplot(data = df[df['Education'] == edu[i-1]], x='MonthlyRate', kde=True)
    plt.axvline(df[df['Education'] == edu[i-1]]['MonthlyRate'].mean(),
                color='red', linestyle='--')
    plt.title(f'Education = {edu[i-1]}')
    plt.tight_layout()

# %% [markdown]
# * Đáng chú ý ở đây rằng mức độ đào tạo cao không đồng nghĩa mức lương được trả cũng cao
# * Khoảng lương được trả là như nhau ở cả 5 mức Education
# * Education mức 3 và 4 cho thấy nhiều nhân viên nhất, phân bố lương ở cả 2 trình độ đào tạo này là gần như nhau và khá đồng đều.
# * Education mức 2 cho thấy hầu hết mức lương được trả thuộc khoảng 10000 - 20000
# * Education mức 5 khá phân tán và ít dữ liệu, trong đó nhiều nhất là nhân viên được trả mức lương 20000
# * Education mức 1 có nhiều nhân viên được trả mức lương 25000 nhất

# %%
plt.figure(figsize=(6,6))
sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('Education').Attrition.count().reset_index()
            , x='Education', y ='Attrition', palette='tab10')
plt.ylabel('Attrition Count')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2457961469.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('Education').Attrition.count().reset_index()
# Text(0, 0.5, 'Attrition Count')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(df[df['Attrition'] == 'Yes'], x='Education', y='MonthlyRate', hue='Attrition')
plt.grid(True, linestyle='--', alpha=0.6)

# %% [markdown]
# * Các nhân viên rời đi chủ yếu có mức đào tạo bằng 3 và 4, mặc dù mức lương được trả vẫn cao

# %% [markdown]
# #### 3.2.3. Theo ngành học

# %%
edu = df['EducationField'].unique()
plt.figure(figsize=(12,8))
plt.subplots(nrows=2, ncols=3, figsize=(12,8))
for i in range(1, len(edu) + 1):
    plt.subplot(2, 3, i)
    sns.histplot(data = df[df['EducationField'] == edu[i-1]], x='MonthlyRate', kde=True)
    plt.axvline(df[df['EducationField'] == edu[i-1]]['MonthlyRate'].mean(),
                color='red', linestyle='--')
    plt.title(f'{edu[i-1]}')
    plt.tight_layout()

# %% [markdown]
# * Phân bố mức lương trong ngành học có sự rõ ràng hơn
# * Life Sciences và Medical có phân bố mức lương khá đồng đều, nhưng Life Sciences có nhiều nhân viên được trả mức lương 15000 - 20000 hơn so với Medical
# * Other và Technical Degree cho thấy mức lương chủ yếu ở khoảng 10000, nhưng Technical Degree cho thấy có nhiều nhân viên được trả mức lương trên 15000 hơn
# * Đối với ngành Marketing, số lượng nhân viên được trả mức lương dưới 10000 nhiều hơn so với Technical Degree và Other.
# * Trong khi đó, ngành Human Resources có số lượng nhân viên thấp nhất trong tất cả các ngành, nhưng mức lương được trả khá cao

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('EducationField').Attrition.count().reset_index()
            , x='EducationField', y ='Attrition', palette='tab10')
plt.ylabel('Attrition Count')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\3836293030.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('EducationField').Attrition.count().reset_index()
# Text(0, 0.5, 'Attrition Count')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(df[df['Attrition'] == 'Yes'], x='EducationField', y='MonthlyRate', hue='Attrition')
plt.grid(True, linestyle='--', alpha=0.6)

# %% [markdown]
# * Life Sciences và Medical là 2 ngành có số lượng nhân viên nghỉ việc nhiều nhất. Mặc dù mức lương được trả khá cao nhưng số lượng nhân viên nghỉ việc lại tập trung nhiều nhất.

# %% [markdown]
# #### 3.2.4. Theo mức độ hài lòng

# %%
job_satis = df['JobSatisfaction'].unique()
plt.figure(figsize=(12,8))
plt.subplots(nrows=2, ncols=2, figsize=(12,8))
for i in range(1, len(job_satis) + 1):
    plt.subplot(2, 2, i)
    sns.histplot(data = df[df['JobSatisfaction'] == job_satis[i-1]], x='MonthlyRate', kde=True)
    plt.axvline(df[df['JobSatisfaction'] == job_satis[i-1]]['MonthlyRate'].mean(), 
                color='red', linestyle='--')
    plt.title(f'Job Satisfaction = {job_satis[i-1]}')
    plt.tight_layout()

# %% [markdown]
# * Mức lương được trả trung bình theo các nhóm đều xấp xỉ $150000
#
# * Phân phối giữa cả 4 nhóm không có nhiều sự khác biệt

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.scatterplot(df[df['Attrition']=='Yes'], x='JobSatisfaction', y='MonthlyRate', hue='Attrition')
plt.grid(True, linestyle='--', alpha=0.6)
plt.subplot(1,2,2)
sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('JobSatisfaction').Attrition.count().reset_index()
            , x='JobSatisfaction', y ='Attrition', palette='tab10')
plt.ylabel('Attrition Count')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\3850904702.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('JobSatisfaction').Attrition.count().reset_index()
# Text(0, 0.5, 'Attrition Count')

# %% [markdown]
# #### 3.2.5. Theo cấp bậc công việc

# %%
level = df['JobLevel'].unique()
plt.figure(figsize=(12,8))
plt.subplots(nrows=2, ncols=3, figsize=(12,8))
for i in range(1, len(level) + 1):
    plt.subplot(2, 3, i)
    sns.histplot(data = df[df['JobLevel'] == level[i-1]], x='MonthlyRate', kde=True)
    plt.axvline(df[df['JobLevel'] == level[i-1]]['MonthlyRate'].mean(),
                color='red', linestyle='--')
    plt.title(f'Job Level {level[i-1]}')
    plt.tight_layout()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.scatterplot(df[df['Attrition']=='Yes'], x='JobLevel', y='MonthlyRate', hue='Attrition')
plt.grid(True, linestyle='--', alpha=0.6)
plt.subplot(1,2,2)
sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('JobLevel').Attrition.count().reset_index()
            , x='JobLevel', y ='Attrition', palette='tab10')
plt.ylabel('Attrition Count')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\3564035057.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('JobLevel').Attrition.count().reset_index()
# Text(0, 0.5, 'Attrition Count')

# %% [markdown]
# * Các nhân viên rời bỏ công ty tập trung chủ yếu ở nhóm có Job Level thấp, trong đó đặc biệt cao ở nhóm số 1
#
# * Điều này cho thấy các nhân viên làm việc ở cấp bậc cao trong công ty thường có xu hướng ở lại

# %% [markdown]
# #### 3.2.6. Theo vị trí công việc

# %%
role = df['JobRole'].unique()
plt.figure(figsize=(12,8))
plt.subplots(nrows=3, ncols=3, figsize=(12,8))
for i in range(1, len(role) + 1):
    plt.subplot(3, 3, i)
    sns.histplot(data = df[df['JobRole'] == role[i-1]], x='MonthlyRate', kde=True)
    plt.axvline(df[df['JobRole'] == level[i-1]]['MonthlyRate'].mean(),
                color='red', linestyle='--')
    plt.title(f'{role[i-1]}')
    plt.tight_layout()

# %% [markdown]
# * Phân bố mức lương có sự chênh lệch giữa các vị trí
#
# * Research Director, Healthcare Representative và Manager là những vị trí có mức lương cao (> 20000)
#
# * Sales Executive, Research Scientist và Labotary Technician có số lượng nhân viên được trả mức lương dưới $10000 khá cao
#
# * Sales Representative có mức lương phân bố khá đều và chủ yếu ở mức trung bình.
#
# * Manufacturing Director phân bố thành 2 nhóm, một nhóm có mức lương thấp (<10000) và 1 nhóm có mức lương cao (>20000)

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('JobRole').Attrition.count().reset_index()
            , y='JobRole', x ='Attrition', palette='tab10')
plt.xlabel('Attrition Count')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\1143703045.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('JobRole').Attrition.count().reset_index()
# Text(0.5, 0, 'Attrition Count')

# %% [markdown]
# * Rõ ràng 3 vị trí có số lượng đông nhân viên được trả mức lương thấp (<10000) có số lượng nhân viên rời đi nhiều nhất
#
# * Sales Representative với mức lương chủ yếu ở mức trung bình cũng chiếm số lượng vừa các nhân viên rời đi

# %% [markdown]
# #### Kết luận 2

# %% [markdown]
# Phân tích ảnh hưởng của mức lương mà công ty trả, có thể nhận thấy:
#
# * Mức lương công ty trả cho nhân viên có thể phụ thuộc vào nhiều yếu tố. Giữa các nhóm số năm làm việc, trình độ đào tạo, ngành học, ... vẫn có thể được trả mức lương cao.
#
# * Mặc dù vậy, mức lương cao không đồng nghĩa với việc nhân viên sẽ muốn ở lại.
#
# * **Vị trí công việc** và **cấp bậc công việc** cho thấy ảnh hưởng lớn đến mức lương được trả và sự rời bỏ công ty của nhân viên
#
# ------
#
# Một số điểm đáng chú ý để phân tích tiếp theo bao gồm:
#
# * Các nhân viên làm việc lâu năm (trên 10 năm) có xu hướng ở lại công ty, trong khi nhóm ít hơn thì ngược lại.
#
# * Nhóm Education 3 và 4 có xu hướng nghỉ việc nhiều hơn
#
# * Life Sciences và Medical có xu hướng rời đi nhiều hơn
#
# * Job Satisfaction mức 1 và 3 có xu hướng rời đi nhiều hơn
#
# * Sales Executive, Research Scientist và Labotary Technician có xu hướng rời đi nhiều hơn

# %% [markdown]
# ### 3.3. Phân tích theo mức thu nhập

# %% [markdown]
# #### 3.3.1. Thu nhập theo số năm làm việc

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df[df['TotalWorkingYears'] >= 20], y='MonthlyIncome', c='r', x='TotalWorkingYears')
sns.scatterplot(data=df[df['TotalWorkingYears'] < 20], y='MonthlyIncome', c='b', x='TotalWorkingYears')
plt.grid(True, linestyle='--', alpha=0.7)
plt.title('Monthly Income by Total Working Years')
# Out:
# Text(0.5, 1.0, 'Monthly Income by Total Working Years')

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(data=df,
            x = 'WorkingYearsRank',
            y = 'MonthlyIncome',
            palette='tab10')
plt.xlabel('Working Years')

plt.subplot(1,2,2)

sns.barplot(data=df,
            x = 'WorkingYearsRank',
            y = 'MonthlyRate',
            palette='tab10')
plt.xlabel('Working Years')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_24528\507102982.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,
# C:\Users\Duong\AppData\Local\Temp\ipykernel_24528\507102982.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,
# Text(0.5, 0, 'Working Years')

# %%
def attrition_percentage_by_categorical_column(column, n_cols = 4, figsize=(8,6)):
    values = df[column].unique()
    value_df = []

    for value in values:
        tmp = df[df[column] == value]['Attrition'].value_counts().reset_index()
        tmp.columns = ['Attrition', 'Count']
        value_df.append(tmp)

    n_cols = n_cols
    n_values = len(values)
    n_rows = int(np.ceil(n_values / n_cols))

    plt.figure(figsize=figsize)
    for i in range(n_values):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.pie(
            value_df[i]['Count'],
            labels=value_df[i]['Attrition'],
            autopct='%.2f%%',
            startangle=90,
        )
        plt.title(f"{column} = {values[i]}")
    
    plt.tight_layout()
    plt.show()

# %%
attrition_percentage_by_categorical_column('WorkingYearsRank', n_cols=2)

# %% [markdown]
# Đối với mức thu nhập hàng tháng, sự phân bố rõ ràng hơn:
# * Mức thu nhập trung bình tăng dần theo số năm làm việc, đặc biệt cao ở nhóm trên 20 năm
# * Nhóm nhân viên có 5-10 năm kinh nghiệm có xu hướng rời bỏ công ty nhiều hơn 3 nhóm còn lại

# %% [markdown]
# #### 3.3.2. Theo mức độ hài lòng công việc

# %%
job_satis = df['JobSatisfaction'].unique()
plt.figure(figsize=(12,8))
plt.subplots(nrows=2, ncols=2, figsize=(12,8))
for i in range(1, len(job_satis) + 1):
    plt.subplot(2, 2, i)
    sns.histplot(data = df[df['JobSatisfaction'] == job_satis[i-1]], x='MonthlyIncome', kde=True)
    plt.axvline(df[df['JobSatisfaction'] == job_satis[i-1]]['MonthlyIncome'].mean(), 
                color='red', linestyle='--')
    plt.title(f'Job Satisfaction = {job_satis[i-1]}')
    plt.tight_layout()

# %%
def attrition_rate_by_col(column):
    attrition_rate = (
    df.groupby(column)['Attrition']
    .apply(lambda x: (x == 'Yes').mean())
    .reset_index(name='AttritionRate')
)
    sns.barplot(data=attrition_rate, x=column, y='AttritionRate', palette='tab10')
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
# sns.scatterplot(df[df['Attrition']=='Yes'], x='JobSatisfaction', y='MonthlyIncome', hue='Attrition')
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.subplot(1,2,2)
attrition_rate = (
    df.groupby('JobSatisfaction')['Attrition']
    .apply(lambda x: (x == 'Yes').mean())
    .reset_index(name='AttritionRate')
)
sns.barplot(data=attrition_rate, x='JobSatisfaction', y='AttritionRate', palette='tab10')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_24528\2056327474.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=attrition_rate, x='JobSatisfaction', y='AttritionRate', palette='tab10')
# <Axes: xlabel='JobSatisfaction', ylabel='AttritionRate'>

# %% [markdown]
# Các nhân viên có mức độ hài lòng với công việc cao cho thấy xu hướng ổn định và ít rời bỏ công ty hơn

# %% [markdown]
# #### 3.3.3. Theo trình độ đào tạo

# %%
edu = df['Education'].unique()
plt.figure(figsize=(12,8))
plt.subplots(nrows=2, ncols=3, figsize=(12,8))
for i in range(1, len(edu) + 1):
    plt.subplot(2, 3, i)
    sns.histplot(data = df[df['Education'] == edu[i-1]], x='MonthlyIncome', kde=True)
    plt.axvline(df[df['Education'] == edu[i-1]]['MonthlyIncome'].mean(),
                color='red', linestyle='--')
    plt.title(f'Education = {edu[i-1]}')
    plt.tight_layout()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.scatterplot(df[df['Attrition']=='Yes'], x='Education', y='MonthlyIncome', hue='Attrition')
plt.grid(True, linestyle='--', alpha=0.6)
plt.subplot(1,2,2)
sns.scatterplot(df[df['Attrition']=='No'], x='Education', y='MonthlyIncome', hue='Attrition')
plt.grid(True, linestyle='--', alpha=0.6)

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('Education').Attrition.count().reset_index()
            , x='Education', y ='Attrition', palette='tab10')
plt.ylabel('Attrition Count')
plt.title('Attrition = Yes')
plt.subplot(1,2,2)
sns.barplot(data=df[df['Attrition'] == 'No'].groupby('Education').Attrition.count().reset_index()
            , x='Education', y ='Attrition', palette='tab10')
plt.ylabel('Attrition Count')
plt.title('Attrition = No')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2069406835.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df[df['Attrition'] == 'Yes'].groupby('Education').Attrition.count().reset_index()
# C:\Users\Duong\AppData\Local\Temp\ipykernel_7612\2069406835.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df[df['Attrition'] == 'No'].groupby('Education').Attrition.count().reset_index()
# Text(0.5, 1.0, 'Attrition = No')

# %% [markdown]
# Phân bố mức lương gần như nhau ở cả 5 nhóm. Bên cạnh đó, tỉ lệ rời bỏ cũng tương tự với tỉ lệ ở lại, điều này cho thấy trình độ đào tạo không có ảnh hưởng đến sự rời bỏ công ty của nhân viên

# %% [markdown]
# #### 3.3.4. Theo phòng ban

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(data=df, x='Department', y='MonthlyIncome', palette='tab10')
attrition_rate = (
    df.groupby('Department')['Attrition']
    .apply(lambda x: (x == 'Yes').mean()).reindex(['Sales', 'Research & Development', 'Human Resources'])
    .reset_index(name='AttritionRate')
)
plt.yticks(fontsize=12)
plt.subplot(1,2,2)
sns.barplot(data=attrition_rate, x='Department', y='AttritionRate', palette='tab10')
plt.ylabel('Attrition Rate')
plt.tight_layout()
plt.yticks(fontsize=12)
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_24528\3239652992.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Department', y='MonthlyIncome', palette='tab10')
# C:\Users\Duong\AppData\Local\Temp\ipykernel_24528\3239652992.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=attrition_rate, x='Department', y='AttritionRate', palette='tab10')
# (array([0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#         0.225]),
#  [Text(0, 0.0, '0.000'),
#   Text(0, 0.025, '0.025'),
#   Text(0, 0.05, '0.050'),
#   Text(0, 0.07500000000000001, '0.075'),
#   Text(0, 0.1, '0.100'),
#   Text(0, 0.125, '0.125'),
#   Text(0, 0.15000000000000002, '0.150'),
# ...

# %%
attrition_percentage_by_categorical_column('Department', n_cols=3, figsize=(12,6))

# %% [markdown]
# ### 3.4. Phân tích theo độ tuổi / thế hệ

# %%
def define_generation(age):
    if age <= 24:
        return 'Gen Z'
    elif age <= 40:
        return 'Millennials'
    elif age <= 56:
        return 'Gen X'
    else:
        return 'Baby Boomers'

df['Generation'] = df['Age'].apply(define_generation)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Generation', hue='Attrition', data=df, palette='Set2')
plt.title('Attrition by Generation', fontsize=16)
plt.xlabel('Generation', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Attrition', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
att_yes = df[df['Generation'] == 'Gen Z'].groupby('Attrition')['Generation'].count().reset_index()
att_yes
# Out:
#   Attrition  Generation
# 0        No          59
# 1       Yes          38

# %%
attrition_percentage_by_categorical_column('Generation', n_cols=2)

# %% [markdown]
# Có thể thấy sự chênh lệch giữa nhóm Gen Z với 3 nhóm tuổi còn lại
#
# * Trong khi tỉ lệ nhân viên nghỉ việc trong nhóm Gen Z đạt gần 40% thì tỉ lệ này ở 3 nhóm còn lại chỉ từ hơn 10% đến khoảng 16%
#
# * Điều này cho thấy nhóm thế hệ trẻ có xu hướng rời bỏ công ty nhiều hơn

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(data=df, x='Generation', y='MonthlyIncome', palette='tab10')
plt.subplot(1,2,2)  
sns.barplot(data=df, x='Generation', y='MonthlyRate', palette='tab10')
# Out:
# C:\Users\Duong\AppData\Local\Temp\ipykernel_24528\210601913.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Generation', y='MonthlyIncome', palette='tab10')
# C:\Users\Duong\AppData\Local\Temp\ipykernel_24528\210601913.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Generation', y='MonthlyRate', palette='tab10')
# <Axes: xlabel='Generation', ylabel='MonthlyRate'>

# %% [markdown]
# * Có thể thấy thu nhập hàng tháng ảnh hưởng khá nhiều đến xu hướng nghỉ việc ở 4 nhóm tuổi
#
# * Mức lương được trả trung bình ở 4 nhóm tuổi không có quá nhiều khác biệt
#
# * Trong khi đó, GenZ là nhóm có mức thu nhập bình quân hàng tháng thấp nhất, điều này cho thấy mối quan hệ giữa mức thu nhập và xu hướng rời bỏ tổ chức ở nhóm này
#
# * Baby Boomers và GenX là 2 nhóm có tỉ lệ nghỉ việc thấp, đồng thời cũng là 2 nhóm có mức thu nhập, mức lương cao
#
# * Millennials có mức thu nhập trung bình thấp hơn gần một nửa so với Baby Boomers nhưng tỉ lệ nghỉ việc không cao, cho thấy độ tuổi cũng có ảnh hưởng đến xu hướng rời bỏ công ty. Độ tuổi cao dường như có môi trường làm việc ổn định hơn

# %% [markdown]
# ### 3.5. Một số yếu tố khác

# %% [markdown]
# #### 3.5.1. Mức độ hài lòng công việc

# %%
attrition_percentage_by_categorical_column('JobSatisfaction', n_cols=2)

# %% [markdown]
# #### 3.5.2. Mức độ hài lòng về môi trường làm việc

# %%
attrition_percentage_by_categorical_column('EnvironmentSatisfaction', n_cols=2)

# %% [markdown]
# #### 3.5.3. Mức độ hài lòng về mối quan hệ

# %%
attrition_percentage_by_categorical_column('RelationshipSatisfaction', n_cols=2)

# %% [markdown]
# #### 3.5.4. Mức độ cân bằng giữa cuộc sống và công việc

# %%
attrition_percentage_by_categorical_column('WorkLifeBalance', n_cols=2)

# %% [markdown]
# #### 3.5.5. Mức độ tham gia vào công việc

# %%
attrition_percentage_by_categorical_column('JobInvolvement', n_cols=2)

# %% [markdown]
# Có thể thấy toàn bộ những yếu tố trên đều có chung đặc điểm là những nhân viên có mức độ hài lòng thấp đều có tỉ lệ nghỉ việc cao hơn những nhóm khác, và tỉ lệ này giảm dần khi mức độ hài lòng cao hơn
