# %%
import pandas as pd
import numpy as np
import torch
import torch.functional as F
import torch.nn as nn 
import torch.optim as optim
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, random_split, DataLoader, WeightedRandomSampler
from torchmetrics.classification import Accuracy, Precision
import os

# %% [markdown]
# ### 1. Data Loading

# %%
df_path = 'Preprocessing/processed_df.parquet'
feature_path = 'Preprocessing/selected_features.parquet'

df = pd.read_parquet(df_path)
features = pd.read_parquet(feature_path)
    
y = df['Attrition'].values
selected_features = features[features['Final'] == 1].index
X = df.loc[:,selected_features].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5, stratify=y_test)

# %% [markdown]
# ### 2. Create Dataset

# %%
class myDataSet(Dataset):
    def __init__(self, data, label):
        super().__init__()
        self.data = torch.tensor(data, dtype=torch.float32)
        self.label = torch.tensor(label, dtype=torch.long)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        return self.data[index], self.label[index]

# %% [markdown]
# ### 3. Create Neural Network

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        
        self.net = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.BatchNorm1d(32),       
            nn.LeakyReLU(0.1),
            
            nn.Linear(32, 64),
            nn.BatchNorm1d(64),
            nn.LeakyReLU(0.1),
            
            nn.Linear(64, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.3),          

            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.3),

            nn.Linear(256, output_dim),
            nn.LogSoftmax(dim=1)      
        )
    
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# #### 4. Parameters & Hyperparameters

# %%
# Parameter
IN_DIM = X.shape[1]
OUT_DIM = 2

# Hyperparameters
LEARNING_RATE = 1e-4
BATCH_SIZE = 16
NUM_EPOCHS = 100

# %%
train_data = myDataSet(X_train, y_train)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)

valid_data = myDataSet(X_valid, y_valid)
valid_loader = DataLoader(valid_data, batch_size=BATCH_SIZE, shuffle=False)

test_data = myDataSet(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = NeuralNetwork(input_dim=IN_DIM, output_dim=OUT_DIM).to(device)

class_counts = np.bincount(y_train)  
class_weights = 1.0 / torch.tensor(class_counts, dtype=torch.float32)
class_weights = class_weights / class_weights.sum() 
class_weights = class_weights.to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights).to(device)  
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
accuracy = Accuracy(task='multiclass', num_classes=OUT_DIM).to(device)
precision = Precision(task='multiclass', average='macro', num_classes=OUT_DIM).to(device)

best_acc = 0.0
best_prec = 0.0
best_model_path = "best_model.pth"

def train():
    global best_acc, best_prec

    for epoch in range(NUM_EPOCHS):
        model.train()
        total_loss = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            preds = model(x)
            
            loss = criterion(preds, y)
            total_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        model.eval()
        acc_score = 0
        prec_score = 0
        
        with torch.no_grad():
            for x, y in valid_loader:
                x, y = x.to(device), y.to(device)
                preds = model(x)
                pred_labels = preds.argmax(dim=1)

                acc_score += accuracy(pred_labels, y)
                prec_score += precision(pred_labels, y)
        
        acc_score /= len(valid_loader)
        prec_score /= len(valid_loader)

        print(f"Epoch {epoch+1}: Loss = {total_loss/len(train_loader):.4f}, Accuracy = {acc_score:.4f}, Precision = {prec_score:.4f}")

        if acc_score > best_acc:
            best_acc = acc_score
            torch.save(model.state_dict(), best_model_path)
            print(f"Best accuracy model saved at epoch {epoch+1} with Accuracy: {best_acc:.4f}, Precision: {best_prec:.4f}")
            
        if prec_score > best_prec:
            best_prec = prec_score
            torch.save(model.state_dict(), best_model_path)
            print(f"Best precision model saved at epoch {epoch+1} with Accuracy: {best_acc:.4f}, Precision: {best_prec:.4f}")

    torch.save(model.state_dict(), "final_model.pth")
    print(f"Training finished. Best Accuracy: {best_acc:.4f}, Best Precision: {best_prec:.4f}")

# %%
train()
# Out:
# Epoch 1: Loss = 0.6911, Accuracy = 0.6167, Precision = 0.5645
# Best accuracy model saved at epoch 1 with Accuracy: 0.6167, Precision: 0.0000
# Best precision model saved at epoch 1 with Accuracy: 0.6167, Precision: 0.5645
# Epoch 2: Loss = 0.6507, Accuracy = 0.6604, Precision = 0.6064
# Best accuracy model saved at epoch 2 with Accuracy: 0.6604, Precision: 0.5645
# Best precision model saved at epoch 2 with Accuracy: 0.6604, Precision: 0.6064
# Epoch 3: Loss = 0.6429, Accuracy = 0.6604, Precision = 0.6023
# Epoch 4: Loss = 0.6454, Accuracy = 0.7167, Precision = 0.6250
# Best accuracy model saved at epoch 4 with Accuracy: 0.7167, Precision: 0.6064
# Best precision model saved at epoch 4 with Accuracy: 0.7167, Precision: 0.6250
# Epoch 5: Loss = 0.6397, Accuracy = 0.6917, Precision = 0.5991
# Epoch 6: Loss = 0.6239, Accuracy = 0.6854, Precision = 0.6088
# Epoch 7: Loss = 0.6302, Accuracy = 0.7229, Precision = 0.6320
# Best accuracy model saved at epoch 7 with Accuracy: 0.7229, Precision: 0.6250
# Best precision model saved at epoch 7 with Accuracy: 0.7229, Precision: 0.6320
# Epoch 8: Loss = 0.5868, Accuracy = 0.7104, Precision = 0.6248
# Epoch 9: Loss = 0.6053, Accuracy = 0.7104, Precision = 0.6423
# Best precision model saved at epoch 9 with Accuracy: 0.7229, Precision: 0.6423
# Epoch 10: Loss = 0.5821, Accuracy = 0.7292, Precision = 0.6255
# Best accuracy model saved at epoch 10 with Accuracy: 0.7292, Precision: 0.6423
# Epoch 11: Loss = 0.5887, Accuracy = 0.7042, Precision = 0.6368
# Epoch 12: Loss = 0.6109, Accuracy = 0.7167, Precision = 0.6317
# Epoch 13: Loss = 0.5714, Accuracy = 0.7229, Precision = 0.6303
# Epoch 14: Loss = 0.5676, Accuracy = 0.7292, Precision = 0.6328
# Epoch 15: Loss = 0.5546, Accuracy = 0.7417, Precision = 0.6214
# Best accuracy model saved at epoch 15 with Accuracy: 0.7417, Precision: 0.6423
# Epoch 16: Loss = 0.5598, Accuracy = 0.7479, Precision = 0.6407
# Best accuracy model saved at epoch 16 with Accuracy: 0.7479, Precision: 0.6423
# Epoch 17: Loss = 0.5376, Accuracy = 0.7354, Precision = 0.6388
# Epoch 18: Loss = 0.5424, Accuracy = 0.7542, Precision = 0.6540
# Best accuracy model saved at epoch 18 with Accuracy: 0.7542, Precision: 0.6423
# Best precision model saved at epoch 18 with Accuracy: 0.7542, Precision: 0.6540
# Epoch 19: Loss = 0.5419, Accuracy = 0.7729, Precision = 0.6571
# Best accuracy model saved at epoch 19 with Accuracy: 0.7729, Precision: 0.6540
# Best precision model saved at epoch 19 with Accuracy: 0.7729, Precision: 0.6571
# Epoch 20: Loss = 0.5301, Accuracy = 0.7542, Precision = 0.6503
# Epoch 21: Loss = 0.5542, Accuracy = 0.7604, Precision = 0.6598
# Best precision model saved at epoch 21 with Accuracy: 0.7729, Precision: 0.6598
# Epoch 22: Loss = 0.5728, Accuracy = 0.7729, Precision = 0.6395
# Epoch 23: Loss = 0.5439, Accuracy = 0.7542, Precision = 0.6270
# Epoch 24: Loss = 0.5140, Accuracy = 0.7729, Precision = 0.6571
# Epoch 25: Loss = 0.5195, Accuracy = 0.7604, Precision = 0.6698
# Best precision model saved at epoch 25 with Accuracy: 0.7729, Precision: 0.6698
# Epoch 26: Loss = 0.5429, Accuracy = 0.7604, Precision = 0.6721
# Best precision model saved at epoch 26 with Accuracy: 0.7729, Precision: 0.6721
# Epoch 27: Loss = 0.5091, Accuracy = 0.7729, Precision = 0.6618
# Epoch 28: Loss = 0.5284, Accuracy = 0.7729, Precision = 0.6728
# Best precision model saved at epoch 28 with Accuracy: 0.7729, Precision: 0.6728
# Epoch 29: Loss = 0.5185, Accuracy = 0.7792, Precision = 0.6928
# Best accuracy model saved at epoch 29 with Accuracy: 0.7792, Precision: 0.6728
# Best precision model saved at epoch 29 with Accuracy: 0.7792, Precision: 0.6928
# Epoch 30: Loss = 0.5197, Accuracy = 0.8042, Precision = 0.6981
# Best accuracy model saved at epoch 30 with Accuracy: 0.8042, Precision: 0.6928
# Best precision model saved at epoch 30 with Accuracy: 0.8042, Precision: 0.6981
# Epoch 31: Loss = 0.5103, Accuracy = 0.7604, Precision = 0.6717
# Epoch 32: Loss = 0.5022, Accuracy = 0.7792, Precision = 0.6478
# Epoch 33: Loss = 0.5092, Accuracy = 0.7979, Precision = 0.6616
# Epoch 34: Loss = 0.5167, Accuracy = 0.7979, Precision = 0.6835
# Epoch 35: Loss = 0.4859, Accuracy = 0.7479, Precision = 0.6577
# Epoch 36: Loss = 0.4766, Accuracy = 0.8042, Precision = 0.6943
# Epoch 37: Loss = 0.5115, Accuracy = 0.7979, Precision = 0.6693
# Epoch 38: Loss = 0.5310, Accuracy = 0.7854, Precision = 0.6579
# Epoch 39: Loss = 0.4864, Accuracy = 0.7979, Precision = 0.7082
# Best precision model saved at epoch 39 with Accuracy: 0.8042, Precision: 0.7082
# Epoch 40: Loss = 0.5039, Accuracy = 0.7854, Precision = 0.6651
# Epoch 41: Loss = 0.5106, Accuracy = 0.7792, Precision = 0.6529
# Epoch 42: Loss = 0.4856, Accuracy = 0.7854, Precision = 0.6927
# Epoch 43: Loss = 0.4850, Accuracy = 0.7854, Precision = 0.6749
# Epoch 44: Loss = 0.4936, Accuracy = 0.7854, Precision = 0.6899
# Epoch 45: Loss = 0.4962, Accuracy = 0.8042, Precision = 0.6956
# Epoch 46: Loss = 0.4913, Accuracy = 0.7792, Precision = 0.6778
# Epoch 47: Loss = 0.4823, Accuracy = 0.7917, Precision = 0.6654
# Epoch 48: Loss = 0.4933, Accuracy = 0.7542, Precision = 0.6535
# Epoch 49: Loss = 0.4876, Accuracy = 0.7792, Precision = 0.6950
# Epoch 50: Loss = 0.4591, Accuracy = 0.8042, Precision = 0.6910
# Epoch 51: Loss = 0.4651, Accuracy = 0.7792, Precision = 0.6833
# Epoch 52: Loss = 0.4638, Accuracy = 0.8042, Precision = 0.6940
# Epoch 53: Loss = 0.4816, Accuracy = 0.7854, Precision = 0.7064
# Epoch 54: Loss = 0.4677, Accuracy = 0.7979, Precision = 0.7082
# Epoch 55: Loss = 0.4766, Accuracy = 0.8042, Precision = 0.6868
# Epoch 56: Loss = 0.4817, Accuracy = 0.7604, Precision = 0.6587
# Epoch 57: Loss = 0.4723, Accuracy = 0.8042, Precision = 0.6998
# Epoch 58: Loss = 0.4561, Accuracy = 0.7917, Precision = 0.6742
# Epoch 59: Loss = 0.4560, Accuracy = 0.7917, Precision = 0.6949
# Epoch 60: Loss = 0.4635, Accuracy = 0.7979, Precision = 0.6995
# Epoch 61: Loss = 0.4607, Accuracy = 0.7917, Precision = 0.6959
# Epoch 62: Loss = 0.4584, Accuracy = 0.8167, Precision = 0.7065
# Best accuracy model saved at epoch 62 with Accuracy: 0.8167, Precision: 0.7082
# Epoch 63: Loss = 0.4543, Accuracy = 0.8167, Precision = 0.7081
# Epoch 64: Loss = 0.4603, Accuracy = 0.8167, Precision = 0.6964
# Epoch 65: Loss = 0.4487, Accuracy = 0.7979, Precision = 0.6659
# Epoch 66: Loss = 0.4487, Accuracy = 0.8042, Precision = 0.7162
# Best precision model saved at epoch 66 with Accuracy: 0.8167, Precision: 0.7162
# Epoch 67: Loss = 0.4681, Accuracy = 0.8104, Precision = 0.6990
# Epoch 68: Loss = 0.4341, Accuracy = 0.7917, Precision = 0.6877
# Epoch 69: Loss = 0.4716, Accuracy = 0.8042, Precision = 0.6692
# Epoch 70: Loss = 0.4454, Accuracy = 0.8292, Precision = 0.7323
# Best accuracy model saved at epoch 70 with Accuracy: 0.8292, Precision: 0.7162
# Best precision model saved at epoch 70 with Accuracy: 0.8292, Precision: 0.7323
# Epoch 71: Loss = 0.4446, Accuracy = 0.8167, Precision = 0.7189
# Epoch 72: Loss = 0.4397, Accuracy = 0.8042, Precision = 0.7090
# Epoch 73: Loss = 0.4512, Accuracy = 0.8104, Precision = 0.7186
# Epoch 74: Loss = 0.4347, Accuracy = 0.7979, Precision = 0.7177
# Epoch 75: Loss = 0.4367, Accuracy = 0.8104, Precision = 0.6937
# Epoch 76: Loss = 0.4228, Accuracy = 0.8042, Precision = 0.6937
# Epoch 77: Loss = 0.4523, Accuracy = 0.8104, Precision = 0.6742
# Epoch 78: Loss = 0.4332, Accuracy = 0.8042, Precision = 0.6706
# Epoch 79: Loss = 0.4302, Accuracy = 0.7917, Precision = 0.6853
# Epoch 80: Loss = 0.4109, Accuracy = 0.8167, Precision = 0.6994
# Epoch 81: Loss = 0.4325, Accuracy = 0.8167, Precision = 0.6994
# Epoch 82: Loss = 0.4398, Accuracy = 0.8042, Precision = 0.6692
# Epoch 83: Loss = 0.4248, Accuracy = 0.7792, Precision = 0.6717
# Epoch 84: Loss = 0.4304, Accuracy = 0.8104, Precision = 0.7017
# Epoch 85: Loss = 0.4201, Accuracy = 0.7854, Precision = 0.6612
# Epoch 86: Loss = 0.3978, Accuracy = 0.7917, Precision = 0.6560
# Epoch 87: Loss = 0.4585, Accuracy = 0.8104, Precision = 0.6990
# Epoch 88: Loss = 0.4133, Accuracy = 0.8042, Precision = 0.6620
# Epoch 89: Loss = 0.4297, Accuracy = 0.8042, Precision = 0.6735
# Epoch 90: Loss = 0.4234, Accuracy = 0.8042, Precision = 0.6735
# Epoch 91: Loss = 0.4020, Accuracy = 0.7792, Precision = 0.6634
# Epoch 92: Loss = 0.4453, Accuracy = 0.7792, Precision = 0.6477
# Epoch 93: Loss = 0.3960, Accuracy = 0.8042, Precision = 0.6931
# Epoch 94: Loss = 0.4088, Accuracy = 0.7917, Precision = 0.6690
# Epoch 95: Loss = 0.4162, Accuracy = 0.7979, Precision = 0.6768
# Epoch 96: Loss = 0.3845, Accuracy = 0.7729, Precision = 0.6692
# Epoch 97: Loss = 0.4294, Accuracy = 0.8042, Precision = 0.6887
# Epoch 98: Loss = 0.3981, Accuracy = 0.8042, Precision = 0.6967
# Epoch 99: Loss = 0.3919, Accuracy = 0.8042, Precision = 0.7003
# Epoch 100: Loss = 0.3851, Accuracy = 0.7917, Precision = 0.6768
# Training finished. Best Accuracy: 0.8292, Best Precision: 0.7323
